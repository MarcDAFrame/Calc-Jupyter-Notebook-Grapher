# %%
from linear_sys_solver import *

# %%
# %matplotlib notebook
equation = input("input equation in the form of f(x) or f(x,z): ")
points = 500
increment = 0.01
if 'z' in equation:
    graph_3D(solve_3D(equation, points=points, increment=increment), mesh_value=10)
else:
    graph_2D(solve_2D(equation, points=points, increment=increment))
# Out:
# input equation in the form of f(x) or f(x,z): sin(x)
# <img src="data:image/png;base64,..." width="640">
